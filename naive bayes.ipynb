# %%
import numpy as np 
import seaborn as sns
import pandas as pd
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier , RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
import statsmodels
from sklearn.naive_bayes import GaussianNB
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
#Get Data
dataset = pd.read_csv('desktop/v_shipment.csv')
dataset
# Out:
# /Users/barankilic/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,17,40,41,42,43,47,48,50,51,52,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              id value_currency latest_status shipper_note  \
# 0      PS6AP2DU            EUR      CANCELED          NaN
# 1      TC0KXIOZ            TRY      CANCELED          NaN
# 2      M4AH4DP8            TRY      CANCELED          NaN
# 3      3OM42TU0            TRY      CANCELED          NaN
# 4      ZK0BMR15            EUR          OPEN          NaN
# ...         ...            ...           ...          ...
# 47364  HPS7J0JL            TRY     DELIVERED          NaN
# 47365  SOW64CCW            TRY     DELIVERED          NaN
# 47366  O43HKT0V            TRY     DELIVERED          NaN
# 47367  1M5A3HY6            TRY     DELIVERED          NaN
# 47368  ZWSWFT0M            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 0                           NaN  2022-02-11 11:14:41.602
# 1                           NaN  2022-02-17 13:55:37.242
# 2                           NaN  2022-02-17 13:49:35.448
# 3                           NaN  2022-02-07 07:15:22.752
# 4                           NaN  2022-02-17 11:17:17.628
# ...                         ...                      ...
# 47364  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47365  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47366  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47367  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47368  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
#
#                      createdat order_id                pricing_id  totalkgds  \
# 0      2022-02-11 11:10:22.380      NaN  620643c46ecc56658317d86a     465.08
# 1      2022-02-14 09:19:45.624      NaN  620a1e7a9fa329591220165a    5907.50
# 2      2022-02-17 13:36:29.193      NaN  620e4f40d1ddb926d6162e16    8000.00
# 3      2022-02-05 13:16:38.813      NaN  61fe787b4df0683a0fc34bad     448.00
# 4      2022-02-17 09:45:20.166      NaN  620e1914c6ac5460e59eb2b4    1700.00
# ...                        ...      ...                       ...        ...
# 47364  2020-04-07 12:17:38.430      NaN  5e8c5f5b76cad97764139545    1792.00
# 47365  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545     896.00
# 47366  2020-04-07 12:17:38.430      NaN  5e8c5f5b76cad97764139545     448.00
# 47367  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545     896.00
# 47368  2020-04-07 12:17:38.440      NaN  5e8c5f5b76cad97764139545     448.00
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  eur_tl  usd_tl  \
# 0      ...                      NaN                      NaN     NaN     NaN
# 1      ...                      NaN                      NaN     NaN     NaN
# 2      ...                      NaN                      NaN     NaN     NaN
# 3      ...                      NaN                      NaN     NaN     NaN
# 4      ...                      NaN                      NaN     NaN     NaN
# ...    ...                      ...                      ...     ...     ...
# 47364  ...                      NaN                      NaN  7.3367  6.7504
# 47365  ...                      NaN                      NaN  7.3367  6.7504
# 47366  ...                      NaN                      NaN  7.3367  6.7504
# 47367  ...                      NaN                      NaN  7.3367  6.7504
# 47368  ...                      NaN                      NaN  7.3367  6.7504
#
#         eur_usd price_base_amount_in_tl price_base_amount_in_usd  \
# 0           NaN                     NaN                      NaN
# 1           NaN                     NaN                      NaN
# 2           NaN                     NaN                      NaN
# 3           NaN                     NaN                      NaN
# 4           NaN                     NaN                      NaN
# ...         ...                     ...                      ...
# 47364  1.086854                  1668.0                   247.10
# 47365  1.086854                   397.0                    58.81
# 47366  1.086854                   499.0                    73.92
# 47367  1.086854                   627.0                    92.88
# 47368  1.086854                   263.0                    38.96
#
#       price_base_amount_in_eur assigned_trip_count               routes
# 0                          NaN                 NaN      İstanbul_Berlin
# 1                          NaN                 NaN     İstanbul_Antalya
# 2                          NaN                 NaN   İstanbul_Rotterdam
# 3                          NaN                 NaN      İstanbul_Berlin
# 4                       520.00                 NaN         Ankara_Essen
# ...                        ...                 ...                  ...
# 47364                   227.35                 NaN       İstanbul_Iğdır
# 47365                    54.11                 NaN       İstanbul_Konya
# 47366                    68.01                 NaN        İstanbul_Kars
# 47367                    85.46                 NaN  İstanbul_Diyarbakır
# 47368                    35.85                 NaN  İstanbul_Kırklareli
#
# [47369 rows x 85 columns]

# %%
dataset = dataset[dataset.invoice_company_title != 'TRENDYOL LOJISTIK A.Ş']
dataset
# Out:
#              id value_currency latest_status shipper_note  \
# 0      PS6AP2DU            EUR      CANCELED          NaN
# 1      TC0KXIOZ            TRY      CANCELED          NaN
# 2      M4AH4DP8            TRY      CANCELED          NaN
# 3      3OM42TU0            TRY      CANCELED          NaN
# 4      ZK0BMR15            EUR          OPEN          NaN
# ...         ...            ...           ...          ...
# 47364  HPS7J0JL            TRY     DELIVERED          NaN
# 47365  SOW64CCW            TRY     DELIVERED          NaN
# 47366  O43HKT0V            TRY     DELIVERED          NaN
# 47367  1M5A3HY6            TRY     DELIVERED          NaN
# 47368  ZWSWFT0M            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 0                           NaN  2022-02-11 11:14:41.602
# 1                           NaN  2022-02-17 13:55:37.242
# 2                           NaN  2022-02-17 13:49:35.448
# 3                           NaN  2022-02-07 07:15:22.752
# 4                           NaN  2022-02-17 11:17:17.628
# ...                         ...                      ...
# 47364  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47365  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47366  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47367  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47368  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
#
#                      createdat order_id                pricing_id  totalkgds  \
# 0      2022-02-11 11:10:22.380      NaN  620643c46ecc56658317d86a     465.08
# 1      2022-02-14 09:19:45.624      NaN  620a1e7a9fa329591220165a    5907.50
# 2      2022-02-17 13:36:29.193      NaN  620e4f40d1ddb926d6162e16    8000.00
# 3      2022-02-05 13:16:38.813      NaN  61fe787b4df0683a0fc34bad     448.00
# 4      2022-02-17 09:45:20.166      NaN  620e1914c6ac5460e59eb2b4    1700.00
# ...                        ...      ...                       ...        ...
# 47364  2020-04-07 12:17:38.430      NaN  5e8c5f5b76cad97764139545    1792.00
# 47365  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545     896.00
# 47366  2020-04-07 12:17:38.430      NaN  5e8c5f5b76cad97764139545     448.00
# 47367  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545     896.00
# 47368  2020-04-07 12:17:38.440      NaN  5e8c5f5b76cad97764139545     448.00
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  eur_tl  usd_tl  \
# 0      ...                      NaN                      NaN     NaN     NaN
# 1      ...                      NaN                      NaN     NaN     NaN
# 2      ...                      NaN                      NaN     NaN     NaN
# 3      ...                      NaN                      NaN     NaN     NaN
# 4      ...                      NaN                      NaN     NaN     NaN
# ...    ...                      ...                      ...     ...     ...
# 47364  ...                      NaN                      NaN  7.3367  6.7504
# 47365  ...                      NaN                      NaN  7.3367  6.7504
# 47366  ...                      NaN                      NaN  7.3367  6.7504
# 47367  ...                      NaN                      NaN  7.3367  6.7504
# 47368  ...                      NaN                      NaN  7.3367  6.7504
#
#         eur_usd price_base_amount_in_tl price_base_amount_in_usd  \
# 0           NaN                     NaN                      NaN
# 1           NaN                     NaN                      NaN
# 2           NaN                     NaN                      NaN
# 3           NaN                     NaN                      NaN
# 4           NaN                     NaN                      NaN
# ...         ...                     ...                      ...
# 47364  1.086854                  1668.0                   247.10
# 47365  1.086854                   397.0                    58.81
# 47366  1.086854                   499.0                    73.92
# 47367  1.086854                   627.0                    92.88
# 47368  1.086854                   263.0                    38.96
#
#       price_base_amount_in_eur assigned_trip_count               routes
# 0                          NaN                 NaN      İstanbul_Berlin
# 1                          NaN                 NaN     İstanbul_Antalya
# 2                          NaN                 NaN   İstanbul_Rotterdam
# 3                          NaN                 NaN      İstanbul_Berlin
# 4                       520.00                 NaN         Ankara_Essen
# ...                        ...                 ...                  ...
# 47364                   227.35                 NaN       İstanbul_Iğdır
# 47365                    54.11                 NaN       İstanbul_Konya
# 47366                    68.01                 NaN        İstanbul_Kars
# 47367                    85.46                 NaN  İstanbul_Diyarbakır
# 47368                    35.85                 NaN  İstanbul_Kırklareli
#
# [47090 rows x 85 columns]

# %%
# Get Delivered Shipments
accepted = ('APPROVED', 'IN_TRANSIT', 'IN_DELIVERY', 'IN_CROSSDOCK', 'DELIVERED', 'IN_PICKUP')

dataset = dataset[dataset.latest_status.isin(accepted)]
dataset
# Out:
#              id value_currency latest_status  \
# 17     UELFE3N7            TRY      APPROVED
# 18     T5L16VEU            TRY      APPROVED
# 19     7UW6C5LA            TRY      APPROVED
# 22     WKDIKX54            TRY      APPROVED
# 28     YOV8PTAB            TRY      APPROVED
# ...         ...            ...           ...
# 47364  HPS7J0JL            TRY     DELIVERED
# 47365  SOW64CCW            TRY     DELIVERED
# 47366  O43HKT0V            TRY     DELIVERED
# 47367  1M5A3HY6            TRY     DELIVERED
# 47368  ZWSWFT0M            TRY     DELIVERED
#
#                                shipper_note                 updatedby  \
# 17                               iç nakliye                       NaN
# 18                               iç nakliye                       NaN
# 19                                      NaN                       NaN
# 22     Brandasının sağlam olması gerekiyor.                       NaN
# 28                                      NaN                       NaN
# ...                                     ...                       ...
# 47364                                   NaN  5fb29424ebbf435b44d7b9a2
# 47365                                   NaN  5fb29424ebbf435b44d7b9a2
# 47366                                   NaN  5fb29424ebbf435b44d7b9a2
# 47367                                   NaN  5fb29424ebbf435b44d7b9a2
# 47368                                   NaN  5fb29424ebbf435b44d7b9a2
#
#                      updatedat                createdat  order_id  \
# 17     2022-02-15 12:48:27.560  2022-02-15 11:15:24.685       NaN
# 18     2022-02-15 12:48:39.953  2022-02-15 11:15:24.685       NaN
# 19     2022-02-17 12:55:14.152  2022-02-17 12:36:58.196       NaN
# 22     2022-02-18 07:02:06.574  2022-02-18 06:38:27.200  Y22-2033
# 28     2022-02-17 09:57:38.270  2022-02-17 09:54:51.406       NaN
# ...                        ...                      ...       ...
# 47364  2021-12-01 16:00:07.453  2020-04-07 12:17:38.430       NaN
# 47365  2021-12-01 16:00:07.453  2020-04-07 12:17:38.420       NaN
# 47366  2021-12-01 16:00:07.453  2020-04-07 12:17:38.430       NaN
# 47367  2021-12-01 16:00:07.453  2020-04-07 12:17:38.420       NaN
# 47368  2021-12-01 16:00:07.453  2020-04-07 12:17:38.440       NaN
#
#                      pricing_id  totalkgds  ... total_cost_amount_in_eur  \
# 17     620b8b420010845a7253d5c6   24000.00  ...                      NaN
# 18     620b8b420010845a7253d5c6   24000.00  ...                      NaN
# 19     620e4165775c6e6c2853107a    8500.00  ...                      NaN
# 22     620f3ed6179cc56359f8b8f2   15000.00  ...                      NaN
# 28     620e1b67b35a1801923ec521    1854.59  ...                      NaN
# ...                         ...        ...  ...                      ...
# 47364  5e8c5f5b76cad97764139545    1792.00  ...                      NaN
# 47365  5e8c5f5b76cad97764139545     896.00  ...                      NaN
# 47366  5e8c5f5b76cad97764139545     448.00  ...                      NaN
# 47367  5e8c5f5b76cad97764139545     896.00  ...                      NaN
# 47368  5e8c5f5b76cad97764139545     448.00  ...                      NaN
#
#       total_cost_amount_in_usd  eur_tl  usd_tl   eur_usd  \
# 17                         NaN     NaN     NaN       NaN
# 18                         NaN     NaN     NaN       NaN
# 19                         NaN     NaN     NaN       NaN
# 22                         NaN     NaN     NaN       NaN
# 28                         NaN     NaN     NaN       NaN
# ...                        ...     ...     ...       ...
# 47364                      NaN  7.3367  6.7504  1.086854
# 47365                      NaN  7.3367  6.7504  1.086854
# 47366                      NaN  7.3367  6.7504  1.086854
# 47367                      NaN  7.3367  6.7504  1.086854
# 47368                      NaN  7.3367  6.7504  1.086854
#
#       price_base_amount_in_tl price_base_amount_in_usd  \
# 17                        NaN                      NaN
# 18                        NaN                      NaN
# 19                     1750.0                      NaN
# 22                     3725.0                      NaN
# 28                        NaN                      NaN
# ...                       ...                      ...
# 47364                  1668.0                   247.10
# 47365                   397.0                    58.81
# 47366                   499.0                    73.92
# 47367                   627.0                    92.88
# 47368                   263.0                    38.96
#
#       price_base_amount_in_eur assigned_trip_count                 routes
# 17                      500.00                 1.0        Mersin_İstanbul
# 18                      500.00                 1.0        Mersin_İstanbul
# 19                         NaN                 1.0       İstanbul_Kocaeli
# 22                         NaN                 1.0         Kocaeli_Manisa
# 28                      290.00                 NaN  İstanbul_Stara Zagora
# ...                        ...                 ...                    ...
# 47364                   227.35                 NaN         İstanbul_Iğdır
# 47365                    54.11                 NaN         İstanbul_Konya
# 47366                    68.01                 NaN          İstanbul_Kars
# 47367                    85.46                 NaN    İstanbul_Diyarbakır
# 47368                    35.85                 NaN    İstanbul_Kırklareli
#
# [38634 rows x 85 columns]

# %%
#Get Spot Prices
price_type = ['SPOT']
#dataset = dataset[dataset.price_type.isin(price_type)]
dataset
# Out:
#              id value_currency latest_status  \
# 17     UELFE3N7            TRY      APPROVED
# 18     T5L16VEU            TRY      APPROVED
# 19     7UW6C5LA            TRY      APPROVED
# 22     WKDIKX54            TRY      APPROVED
# 28     YOV8PTAB            TRY      APPROVED
# ...         ...            ...           ...
# 47364  HPS7J0JL            TRY     DELIVERED
# 47365  SOW64CCW            TRY     DELIVERED
# 47366  O43HKT0V            TRY     DELIVERED
# 47367  1M5A3HY6            TRY     DELIVERED
# 47368  ZWSWFT0M            TRY     DELIVERED
#
#                                shipper_note                 updatedby  \
# 17                               iç nakliye                       NaN
# 18                               iç nakliye                       NaN
# 19                                      NaN                       NaN
# 22     Brandasının sağlam olması gerekiyor.                       NaN
# 28                                      NaN                       NaN
# ...                                     ...                       ...
# 47364                                   NaN  5fb29424ebbf435b44d7b9a2
# 47365                                   NaN  5fb29424ebbf435b44d7b9a2
# 47366                                   NaN  5fb29424ebbf435b44d7b9a2
# 47367                                   NaN  5fb29424ebbf435b44d7b9a2
# 47368                                   NaN  5fb29424ebbf435b44d7b9a2
#
#                      updatedat                createdat  order_id  \
# 17     2022-02-15 12:48:27.560  2022-02-15 11:15:24.685       NaN
# 18     2022-02-15 12:48:39.953  2022-02-15 11:15:24.685       NaN
# 19     2022-02-17 12:55:14.152  2022-02-17 12:36:58.196       NaN
# 22     2022-02-18 07:02:06.574  2022-02-18 06:38:27.200  Y22-2033
# 28     2022-02-17 09:57:38.270  2022-02-17 09:54:51.406       NaN
# ...                        ...                      ...       ...
# 47364  2021-12-01 16:00:07.453  2020-04-07 12:17:38.430       NaN
# 47365  2021-12-01 16:00:07.453  2020-04-07 12:17:38.420       NaN
# 47366  2021-12-01 16:00:07.453  2020-04-07 12:17:38.430       NaN
# 47367  2021-12-01 16:00:07.453  2020-04-07 12:17:38.420       NaN
# 47368  2021-12-01 16:00:07.453  2020-04-07 12:17:38.440       NaN
#
#                      pricing_id  totalkgds  ... total_cost_amount_in_eur  \
# 17     620b8b420010845a7253d5c6   24000.00  ...                      NaN
# 18     620b8b420010845a7253d5c6   24000.00  ...                      NaN
# 19     620e4165775c6e6c2853107a    8500.00  ...                      NaN
# 22     620f3ed6179cc56359f8b8f2   15000.00  ...                      NaN
# 28     620e1b67b35a1801923ec521    1854.59  ...                      NaN
# ...                         ...        ...  ...                      ...
# 47364  5e8c5f5b76cad97764139545    1792.00  ...                      NaN
# 47365  5e8c5f5b76cad97764139545     896.00  ...                      NaN
# 47366  5e8c5f5b76cad97764139545     448.00  ...                      NaN
# 47367  5e8c5f5b76cad97764139545     896.00  ...                      NaN
# 47368  5e8c5f5b76cad97764139545     448.00  ...                      NaN
#
#       total_cost_amount_in_usd  eur_tl  usd_tl   eur_usd  \
# 17                         NaN     NaN     NaN       NaN
# 18                         NaN     NaN     NaN       NaN
# 19                         NaN     NaN     NaN       NaN
# 22                         NaN     NaN     NaN       NaN
# 28                         NaN     NaN     NaN       NaN
# ...                        ...     ...     ...       ...
# 47364                      NaN  7.3367  6.7504  1.086854
# 47365                      NaN  7.3367  6.7504  1.086854
# 47366                      NaN  7.3367  6.7504  1.086854
# 47367                      NaN  7.3367  6.7504  1.086854
# 47368                      NaN  7.3367  6.7504  1.086854
#
#       price_base_amount_in_tl price_base_amount_in_usd  \
# 17                        NaN                      NaN
# 18                        NaN                      NaN
# 19                     1750.0                      NaN
# 22                     3725.0                      NaN
# 28                        NaN                      NaN
# ...                       ...                      ...
# 47364                  1668.0                   247.10
# 47365                   397.0                    58.81
# 47366                   499.0                    73.92
# 47367                   627.0                    92.88
# 47368                   263.0                    38.96
#
#       price_base_amount_in_eur assigned_trip_count                 routes
# 17                      500.00                 1.0        Mersin_İstanbul
# 18                      500.00                 1.0        Mersin_İstanbul
# 19                         NaN                 1.0       İstanbul_Kocaeli
# 22                         NaN                 1.0         Kocaeli_Manisa
# 28                      290.00                 NaN  İstanbul_Stara Zagora
# ...                        ...                 ...                    ...
# 47364                   227.35                 NaN         İstanbul_Iğdır
# 47365                    54.11                 NaN         İstanbul_Konya
# 47366                    68.01                 NaN          İstanbul_Kars
# 47367                    85.46                 NaN    İstanbul_Diyarbakır
# 47368                    35.85                 NaN    İstanbul_Kırklareli
#
# [38634 rows x 85 columns]

# %%
# GET pickup and dropoffs
routes = ('İstanbul_İstanbul', 'İstanbul_İzmir', 'İstanbul_Ankara', 'İstanbul_Kocaeli', 'İstanbul_Bursa', 
          'İstanbul_Antalya', 
          'Kocaeli_İstanbul', 'İstanbul_Adana','İstanbul_Tekirdağ','İstanbul_Gaziantep','İstanbul_Balıkesir',
          'İstanbul_Eskişehir','İstanbul_Muğla','Kocaeli_İzmir','İstanbul_Mersin','İstanbul_Sakarya',
          'İstanbul_Samsun','Kocaeli_Ankara','İstanbul_Denizli','İstanbul_Kayseri')
dataset = dataset[dataset.routes.isin(routes)]
dataset
# Out:
#              id value_currency latest_status shipper_note  \
# 19     7UW6C5LA            TRY      APPROVED          NaN
# 36     OPRPPJLC            TRY      APPROVED          NaN
# 44     LZCXU45R            TRY     IN_PICKUP          NaN
# 51     KW6ELGIV            TRY     IN_PICKUP          NaN
# 52     2ANOSFU7            TRY     IN_PICKUP          NaN
# ...         ...            ...           ...          ...
# 47349  8GINZKBD            TRY     DELIVERED          NaN
# 47350  0HIH977T            TRY     DELIVERED          NaN
# 47351  GJB7JF6V            TRY     DELIVERED          NaN
# 47355  02GQTXWP            TRY     DELIVERED          NaN
# 47360  IVDHPM72            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 19                          NaN  2022-02-17 12:55:14.152
# 36                          NaN  2022-02-18 07:50:07.630
# 44                          NaN  2022-02-17 12:24:48.700
# 51                          NaN  2022-02-18 07:44:16.564
# 52                          NaN  2022-02-18 07:44:16.564
# ...                         ...                      ...
# 47349  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47350  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47351  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47355  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 47360  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
#
#                      createdat    order_id                pricing_id  \
# 19     2022-02-17 12:36:58.196         NaN  620e4165775c6e6c2853107a
# 36     2022-02-17 11:52:53.991         NaN  620e37097f88244abc95194a
# 44     2022-02-17 12:16:11.160         NaN                       NaN
# 51     2022-02-18 07:37:46.718  5100244189                       NaN
# 52     2022-02-18 07:37:46.838  5100244164                       NaN
# ...                        ...         ...                       ...
# 47349  2020-04-07 12:17:38.420         NaN  5e8c5f5b76cad97764139545
# 47350  2020-04-07 12:17:38.440         NaN  5e8c5f5b76cad97764139545
# 47351  2020-04-07 12:17:38.450         NaN  5e8c5f5b76cad97764139545
# 47355  2020-04-07 12:17:38.440         NaN  5e8c5f5b76cad97764139545
# 47360  2020-04-07 12:17:38.101         NaN  5e8c5f5b76cad97764139545
#
#        totalkgds  ... total_cost_amount_in_eur total_cost_amount_in_usd  \
# 19        8500.0  ...                      NaN                      NaN
# 36         750.0  ...                      NaN                      NaN
# 44        1152.0  ...                     0.01                     0.01
# 51          34.0  ...                     4.96                     5.64
# 52        2060.0  ...                   300.55                   341.61
# ...          ...  ...                      ...                      ...
# 47349      448.0  ...                      NaN                      NaN
# 47350      448.0  ...                      NaN                      NaN
# 47351      448.0  ...                      NaN                      NaN
# 47355      896.0  ...                      NaN                      NaN
# 47360      448.0  ...                      NaN                      NaN
#
#         eur_tl   usd_tl   eur_usd price_base_amount_in_tl  \
# 19         NaN      NaN       NaN                  1750.0
# 36     15.4899  13.6280  1.136623                   135.0
# 44     15.4899  13.6280  1.136623                   664.0
# 51     15.4899  13.6280  1.136623                   409.5
# 52     15.4899  13.6280  1.136623                   679.8
# ...        ...      ...       ...                     ...
# 47349   7.3367   6.7504  1.086854                   243.0
# 47350   7.3367   6.7504  1.086854                   211.0
# 47351   7.3367   6.7504  1.086854                   283.0
# 47355   7.3367   6.7504  1.086854                   363.0
# 47360   7.3367   6.7504  1.086854                   216.0
#
#       price_base_amount_in_usd price_base_amount_in_eur assigned_trip_count  \
# 19                         NaN                      NaN                 1.0
# 36                        9.91                     8.72                 NaN
# 44                       48.72                    42.87                 2.0
# 51                       30.05                    26.44                 2.0
# 52                       49.88                    43.89                 2.0
# ...                        ...                      ...                 ...
# 47349                    36.00                    33.12                 NaN
# 47350                    31.26                    28.76                 NaN
# 47351                    41.92                    38.57                 NaN
# 47355                    53.77                    49.48                 NaN
# 47360                    32.00                    29.44                 NaN
#
#                    routes
# 19       İstanbul_Kocaeli
# 36       İstanbul_Kocaeli
# 44          Kocaeli_İzmir
# 51        İstanbul_Samsun
# 52      İstanbul_İstanbul
# ...                   ...
# 47349    İstanbul_Kayseri
# 47350   İstanbul_İstanbul
# 47351      İstanbul_Muğla
# 47355   İstanbul_İstanbul
# 47360  İstanbul_Balıkesir
#
# [18260 rows x 85 columns]

# %%
# Get Applicable Columns
data = pd.concat([dataset['latest_status'],dataset['totalkgds'],dataset['pickup_city'],dataset['dropoff_city'] ,dataset['pickup_address_type'], dataset['dropoff_address_type'],
                  dataset['category'], dataset['price_type'], 
                  dataset['shipment_type'], dataset['vehicle_type'],dataset['vehicle_body_type'],
                  dataset['vehicle_package_type'], dataset['vehicle_way_of_loading'],
                  dataset['vehicle_tonnage_per_vehicle'],dataset['payment_option'],
                  dataset['invoice_type'], dataset['tenant_signup_flow'], 
                  dataset['total_cost_amount_in_tl'], dataset['usd_tl'],
                  dataset['price_base_amount_in_tl']
                 ,dataset['routes']], axis = 1)
data
# Out:
#       latest_status  totalkgds pickup_city dropoff_city pickup_address_type  \
# 19         APPROVED     8500.0    İstanbul      Kocaeli           WORKSPACE
# 36         APPROVED      750.0    İstanbul      Kocaeli             FACTORY
# 44        IN_PICKUP     1152.0     Kocaeli        İzmir           WAREHOUSE
# 51        IN_PICKUP       34.0    İstanbul       Samsun             FACTORY
# 52        IN_PICKUP     2060.0    İstanbul     İstanbul             FACTORY
# ...             ...        ...         ...          ...                 ...
# 47349     DELIVERED      448.0    İstanbul      Kayseri           WAREHOUSE
# 47350     DELIVERED      448.0    İstanbul     İstanbul           WAREHOUSE
# 47351     DELIVERED      448.0    İstanbul        Muğla           WAREHOUSE
# 47355     DELIVERED      896.0    İstanbul     İstanbul           WAREHOUSE
# 47360     DELIVERED      448.0    İstanbul    Balıkesir           WAREHOUSE
#
#       dropoff_address_type  category price_type shipment_type vehicle_type  \
# 19               WAREHOUSE  DRY_FOOD     MANUAL           FTL  _10_WHEELER
# 36               WAREHOUSE  DRY_FOOD        NaN           LTL          NaN
# 44                   OTHER     OTHER        NaN           LTL          NaN
# 51               WAREHOUSE   PLASTIC        NaN           LTL          NaN
# 52               WAREHOUSE   PLASTIC        NaN           LTL          NaN
# ...                    ...       ...        ...           ...          ...
# 47349                OTHER  DRY_FOOD        NaN           LTL          NaN
# 47350                OTHER  DRY_FOOD        NaN           LTL          NaN
# 47351                OTHER  DRY_FOOD        NaN           LTL          NaN
# 47355                OTHER  DRY_FOOD        NaN           LTL          NaN
# 47360                OTHER  DRY_FOOD        NaN           LTL          NaN
#
#        ... vehicle_package_type                 vehicle_way_of_loading  \
# 19     ...                  NaN  FROM_THE_RAMP_BY_TRANSPALLET_FORKLIFT
# 36     ...                  NaN                                    NaN
# 44     ...                  NaN                                    NaN
# 51     ...                  NaN                                    NaN
# 52     ...                  NaN                                    NaN
# ...    ...                  ...                                    ...
# 47349  ...                  NaN                                    NaN
# 47350  ...                  NaN                                    NaN
# 47351  ...                  NaN                                    NaN
# 47355  ...                  NaN                                    NaN
# 47360  ...                  NaN                                    NaN
#
#       vehicle_tonnage_per_vehicle  payment_option invoice_type  \
# 19                            8.5       PAY_LATER          NaN
# 36                            NaN       PAY_LATER          NaN
# 44                            NaN       PAY_LATER          NaN
# 51                            NaN       PAY_LATER          NaN
# 52                            NaN       PAY_LATER          NaN
# ...                           ...             ...          ...
# 47349                         NaN       PAY_LATER          NaN
# 47350                         NaN       PAY_LATER          NaN
# 47351                         NaN       PAY_LATER          NaN
# 47355                         NaN       PAY_LATER          NaN
# 47360                         NaN       PAY_LATER          NaN
#
#       tenant_signup_flow total_cost_amount_in_tl   usd_tl  \
# 19           SELF_SIGNUP                     NaN      NaN
# 36           SELF_SIGNUP                     NaN  13.6280
# 44           SELF_SIGNUP                    0.13  13.6280
# 51           SELF_SIGNUP                   76.84  13.6280
# 52           SELF_SIGNUP                 4655.50  13.6280
# ...                  ...                     ...      ...
# 47349        SELF_SIGNUP                     NaN   6.7504
# 47350        SELF_SIGNUP                     NaN   6.7504
# 47351        SELF_SIGNUP                     NaN   6.7504
# 47355        SELF_SIGNUP                     NaN   6.7504
# 47360        SELF_SIGNUP                     NaN   6.7504
#
#        price_base_amount_in_tl              routes
# 19                      1750.0    İstanbul_Kocaeli
# 36                       135.0    İstanbul_Kocaeli
# 44                       664.0       Kocaeli_İzmir
# 51                       409.5     İstanbul_Samsun
# 52                       679.8   İstanbul_İstanbul
# ...                        ...                 ...
# 47349                    243.0    İstanbul_Kayseri
# 47350                    211.0   İstanbul_İstanbul
# 47351                    283.0      İstanbul_Muğla
# 47355                    363.0   İstanbul_İstanbul
# 47360                    216.0  İstanbul_Balıkesir
#
# [18260 rows x 21 columns]

# %%
#Drop Price type and Latest Status
data = data.drop(columns= 'price_type')


data
# Out:
#       latest_status  totalkgds pickup_city dropoff_city pickup_address_type  \
# 19         APPROVED     8500.0    İstanbul      Kocaeli           WORKSPACE
# 36         APPROVED      750.0    İstanbul      Kocaeli             FACTORY
# 44        IN_PICKUP     1152.0     Kocaeli        İzmir           WAREHOUSE
# 51        IN_PICKUP       34.0    İstanbul       Samsun             FACTORY
# 52        IN_PICKUP     2060.0    İstanbul     İstanbul             FACTORY
# ...             ...        ...         ...          ...                 ...
# 47349     DELIVERED      448.0    İstanbul      Kayseri           WAREHOUSE
# 47350     DELIVERED      448.0    İstanbul     İstanbul           WAREHOUSE
# 47351     DELIVERED      448.0    İstanbul        Muğla           WAREHOUSE
# 47355     DELIVERED      896.0    İstanbul     İstanbul           WAREHOUSE
# 47360     DELIVERED      448.0    İstanbul    Balıkesir           WAREHOUSE
#
#       dropoff_address_type  category shipment_type vehicle_type  \
# 19               WAREHOUSE  DRY_FOOD           FTL  _10_WHEELER
# 36               WAREHOUSE  DRY_FOOD           LTL          NaN
# 44                   OTHER     OTHER           LTL          NaN
# 51               WAREHOUSE   PLASTIC           LTL          NaN
# 52               WAREHOUSE   PLASTIC           LTL          NaN
# ...                    ...       ...           ...          ...
# 47349                OTHER  DRY_FOOD           LTL          NaN
# 47350                OTHER  DRY_FOOD           LTL          NaN
# 47351                OTHER  DRY_FOOD           LTL          NaN
# 47355                OTHER  DRY_FOOD           LTL          NaN
# 47360                OTHER  DRY_FOOD           LTL          NaN
#
#       vehicle_body_type vehicle_package_type  \
# 19                STEEL                  NaN
# 36                  NaN                  NaN
# 44                  NaN                  NaN
# 51                  NaN                  NaN
# 52                  NaN                  NaN
# ...                 ...                  ...
# 47349               NaN                  NaN
# 47350               NaN                  NaN
# 47351               NaN                  NaN
# 47355               NaN                  NaN
# 47360               NaN                  NaN
#
#                       vehicle_way_of_loading  vehicle_tonnage_per_vehicle  \
# 19     FROM_THE_RAMP_BY_TRANSPALLET_FORKLIFT                          8.5
# 36                                       NaN                          NaN
# 44                                       NaN                          NaN
# 51                                       NaN                          NaN
# 52                                       NaN                          NaN
# ...                                      ...                          ...
# 47349                                    NaN                          NaN
# 47350                                    NaN                          NaN
# 47351                                    NaN                          NaN
# 47355                                    NaN                          NaN
# 47360                                    NaN                          NaN
#
#       payment_option invoice_type tenant_signup_flow  total_cost_amount_in_tl  \
# 19         PAY_LATER          NaN        SELF_SIGNUP                      NaN
# 36         PAY_LATER          NaN        SELF_SIGNUP                      NaN
# 44         PAY_LATER          NaN        SELF_SIGNUP                     0.13
# 51         PAY_LATER          NaN        SELF_SIGNUP                    76.84
# 52         PAY_LATER          NaN        SELF_SIGNUP                  4655.50
# ...              ...          ...                ...                      ...
# 47349      PAY_LATER          NaN        SELF_SIGNUP                      NaN
# 47350      PAY_LATER          NaN        SELF_SIGNUP                      NaN
# 47351      PAY_LATER          NaN        SELF_SIGNUP                      NaN
# 47355      PAY_LATER          NaN        SELF_SIGNUP                      NaN
# 47360      PAY_LATER          NaN        SELF_SIGNUP                      NaN
#
#         usd_tl  price_base_amount_in_tl              routes
# 19         NaN                   1750.0    İstanbul_Kocaeli
# 36     13.6280                    135.0    İstanbul_Kocaeli
# 44     13.6280                    664.0       Kocaeli_İzmir
# 51     13.6280                    409.5     İstanbul_Samsun
# 52     13.6280                    679.8   İstanbul_İstanbul
# ...        ...                      ...                 ...
# 47349   6.7504                    243.0    İstanbul_Kayseri
# 47350   6.7504                    211.0   İstanbul_İstanbul
# 47351   6.7504                    283.0      İstanbul_Muğla
# 47355   6.7504                    363.0   İstanbul_İstanbul
# 47360   6.7504                    216.0  İstanbul_Balıkesir
#
# [18260 rows x 20 columns]

# %%
#Split Data by Shipment Type
data_ftl = data[data.shipment_type == 'FTL']

# %%
data_ftl = data_ftl.drop(columns = 'shipment_type')
data_ftl = data_ftl.drop(columns = 'latest_status')
data_ftl = data_ftl.drop(columns = 'price_base_amount_in_tl')
data_ftl = data_ftl.drop(columns = 'payment_option')
data_ftl = data_ftl.drop(columns = 'tenant_signup_flow')
data_ftl = data_ftl.drop(columns = 'invoice_type')

# %%
labelencoder = LabelEncoder()
data_ftl['category'] = labelencoder.fit_transform(data_ftl['category'])
data_ftl['vehicle_type'] = labelencoder.fit_transform(data_ftl['vehicle_type'])
data_ftl['vehicle_body_type'] = labelencoder.fit_transform(data_ftl['vehicle_body_type'])
data_ftl['vehicle_package_type'] = labelencoder.fit_transform(data_ftl['vehicle_package_type'])
data_ftl['vehicle_way_of_loading'] = labelencoder.fit_transform(data_ftl['vehicle_way_of_loading'])
data_ftl['pickup_address_type'] = labelencoder.fit_transform(data_ftl['pickup_address_type'])
data_ftl['dropoff_address_type'] = labelencoder.fit_transform(data_ftl['dropoff_address_type'])
data_ftl['routes'] = labelencoder.fit_transform(data_ftl['routes'])
data_ftl['pickup_city'] = labelencoder.fit_transform(data_ftl['pickup_city'])
data_ftl['dropoff_city'] = labelencoder.fit_transform(data_ftl['dropoff_city'])


data_ftl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1121 entries, 19 to 35181
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalkgds                    1121 non-null   float64
#  1   pickup_city                  1121 non-null   int64
#  2   dropoff_city                 1121 non-null   int64
#  3   pickup_address_type          1121 non-null   int64
#  4   dropoff_address_type         1121 non-null   int64
#  5   category                     1121 non-null   int64
#  6   vehicle_type                 1121 non-null   int64
#  7   vehicle_body_type            1121 non-null   int64
#  8   vehicle_package_type         1121 non-null   int64
#  9   vehicle_way_of_loading       1121 non-null   int64
#  10  vehicle_tonnage_per_vehicle  1121 non-null   float64
#  11  total_cost_amount_in_tl      1106 non-null   float64
#  12  usd_tl                       1120 non-null   float64
#  13  routes                       1121 non-null   int64
# dtypes: float64(4), int64(10)
# memory usage: 131.4 KB

# %%
data_ftl = data_ftl.dropna()
data_ftl.totalkgds = data_ftl.totalkgds.astype(int)
data_ftl.vehicle_tonnage_per_vehicle = data_ftl.vehicle_tonnage_per_vehicle.astype(int)
data_ftl.total_cost_amount_in_tl = data_ftl.total_cost_amount_in_tl.astype(int)
data_ftl.usd_tl = data_ftl.usd_tl.astype(int)

data_ftl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1106 entries, 61 to 35181
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalkgds                    1106 non-null   int64
#  1   pickup_city                  1106 non-null   int64
#  2   dropoff_city                 1106 non-null   int64
#  3   pickup_address_type          1106 non-null   int64
#  4   dropoff_address_type         1106 non-null   int64
#  5   category                     1106 non-null   int64
#  6   vehicle_type                 1106 non-null   int64
#  7   vehicle_body_type            1106 non-null   int64
#  8   vehicle_package_type         1106 non-null   int64
#  9   vehicle_way_of_loading       1106 non-null   int64
#  10  vehicle_tonnage_per_vehicle  1106 non-null   int64
#  11  total_cost_amount_in_tl      1106 non-null   int64
#  12  usd_tl                       1106 non-null   int64
#  13  routes                       1106 non-null   int64
# dtypes: int64(14)
# memory usage: 129.6 KB

# %%
data_ftl = data_ftl.drop(columns = ['pickup_city', 'dropoff_city','vehicle_way_of_loading',
                                    'vehicle_tonnage_per_vehicle', 'vehicle_type','vehicle_body_type'])

# %%
X_train_ftl, X_test_ftl, y_train_ftl, y_test_ftl = train_test_split(data_ftl.drop(columns = 'total_cost_amount_in_tl'), data_ftl.total_cost_amount_in_tl, test_size=0.2, random_state=0)
X_train_ftl.shape, X_test_ftl.shape
# Out:
# ((884, 7), (222, 7))

# %%
model = GaussianNB()

# %%
model.fit(X_train_ftl,y_train_ftl)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_train_ftl)

# %%
metrics.accuracy_score(y_train_ftl,y_pred)
# Out:
# 0.29298642533936653

# %%
predictions = model.predict(X_test_ftl)

# %%
metrics.accuracy_score(y_test_ftl,predictions)
# Out:
# 0.17117117117117117

# %%
# Out:
#   File "/var/folders/07/73n4qj9d0fg68hxg63thmpd00000gp/T/ipykernel_61224/1770707612.py", line 2
#     pathlib.Path(__naive%20bayes__).parent.resolve()
#                            ^
# SyntaxError: invalid syntax
